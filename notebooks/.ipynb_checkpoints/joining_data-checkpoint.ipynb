# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import requests 
from IPython.display import JSON
import json
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Merging of business outlet information from foursquare and yelp and then focussing on food outlets 
#specifically for further analysis as majority of business outlets are food outlets (553 out of 790
#food square businesses and almost all 2000 yelp businesses are food outlets).

df_fsquare = pd.read_csv('fsquare_POIs_for_100_BikeStns.csv')

df_fsquare_food = df_fsquare[df_fsquare['poi_bsns_category'] == 'Dining and Drinking']

df_yelp = pd.read_csv('yelp_POIs_for_100_BikeStns.csv')

df_merge_fs_yelp = pd.concat([df_fsquare_food, df_yelp], ignore_index=True, sort=False)

df_merge_fs_yelp = df_merge_fs_yelp.sort_values(by=['review_count', 'poi_distance_from_bike_stn'],
                                                   ascending=[False, True]
                                               )

df_merge_fs_yelp.drop_duplicates(subset=['poi_id'], keep='first', inplace=True)

df_merge_fs_yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1072 entries, 1073 to 506
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   poi_id                      1072 non-null   object
#  1   poi_name                    1072 non-null   object
#  2   poi_distance_from_bike_stn  1072 non-null   int64
#  3   poi_latitude                1072 non-null   float64
#  4   poi_longitude               1072 non-null   float64
#  5   bike_station_id             1072 non-null   object
#  6   poi_bsns_category           1072 non-null   object
#  7   review_count                539 non-null    float64
#  8   rating                      539 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 83.8+ KB

# %%
df_bike_stns = pd.read_csv('london_city_bikes_stns.csv')

df_bike_stns.rename(columns = {'station_id':'bike_station_id'}, inplace = True) 

df_join = pd.merge(df_bike_stns, df_merge_fs_yelp, on='bike_station_id')

df_join.to_csv("merged_poi_info_for_100_BikeStns.csv", index=False)

df_join.info()

#After merging and joining of yelp and foursquare data, total of 2553 food outlets selected out of total 2900 
#business outlets.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1072 entries, 0 to 1071
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   network_city                1072 non-null   object
#  1   network_name                1072 non-null   object
#  2   station_name                1072 non-null   object
#  3   bike_station_id             1072 non-null   object
#  4   station_latitude            1072 non-null   float64
#  5   station_longitude           1072 non-null   float64
#  6   empty_slots                 1072 non-null   int64
#  7   free_bikes                  1072 non-null   int64
#  8   total_bikes                 1072 non-null   int64
#  9   poi_id                      1072 non-null   object
#  10  poi_name                    1072 non-null   object
#  11  poi_distance_from_bike_stn  1072 non-null   int64
#  12  poi_latitude                1072 non-null   float64
#  13  poi_longitude               1072 non-null   float64
#  14  poi_bsns_category           1072 non-null   object
#  15  review_count                539 non-null    float64
#  16  rating                      539 non-null    float64
# dtypes: float64(6), int64(4), object(7)
# memory usage: 150.8+ KB

# %%
#validation of sample record to ensure that merged data reflects original transactional data
#from yelp and foursquare.

df_join[df_join['bike_station_id'] == 'f8dfc16e9f34e5c21bfc24efe8831549']
# Out:
#     network_city      network_name                        station_name  \
# 847       London  santander-cycles  000960 - Hop Exchange, The Borough
# 848       London  santander-cycles  000960 - Hop Exchange, The Borough
# 849       London  santander-cycles  000960 - Hop Exchange, The Borough
# 850       London  santander-cycles  000960 - Hop Exchange, The Borough
# 851       London  santander-cycles  000960 - Hop Exchange, The Borough
# 852       London  santander-cycles  000960 - Hop Exchange, The Borough
# 853       London  santander-cycles  000960 - Hop Exchange, The Borough
# 854       London  santander-cycles  000960 - Hop Exchange, The Borough
# 855       London  santander-cycles  000960 - Hop Exchange, The Borough
# 856       London  santander-cycles  000960 - Hop Exchange, The Borough
# 857       London  santander-cycles  000960 - Hop Exchange, The Borough
# 858       London  santander-cycles  000960 - Hop Exchange, The Borough
# 859       London  santander-cycles  000960 - Hop Exchange, The Borough
# 860       London  santander-cycles  000960 - Hop Exchange, The Borough
# 861       London  santander-cycles  000960 - Hop Exchange, The Borough
#
#                       bike_station_id  station_latitude  station_longitude  \
# 847  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 848  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 849  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 850  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 851  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 852  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 853  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 854  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 855  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 856  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 857  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 858  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 859  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 860  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
# 861  f8dfc16e9f34e5c21bfc24efe8831549         51.504628          -0.091774
#
#      empty_slots  free_bikes  total_bikes                    poi_id  \
# 847           10          46           56    KzYd2EaFvmu63wqTIektSA
# 848           10          46           56    iVs-N80pYt58IKqFBP1IHA
# 849           10          46           56    nowLq0ziL3B0Acpyhgs_RA
# 850           10          46           56    VFt0kawsBqqNIh9UJYS4tg
# 851           10          46           56    4CGgn2MmN5Z7B6GAlMAcxQ
# 852           10          46           56    bibItX92d7LSCVThLeXb8Q
# 853           10          46           56    DJH9kKABJZHkJ4Xz8b168w
# 854           10          46           56    VSrnYJMirUi6ZQna_qtwMw
# 855           10          46           56    GtjaGgiKiMPxjPcPtxgUiQ
# 856           10          46           56    GTImh5FbaxKTo8TXyxRT4w
# 857           10          46           56    pMZ4XI-RsAxY6YK3xHVFJA
# 858           10          46           56  5946b8a617556232c3759fe9
# 859           10          46           56  5b4736f5835c9a002c447b88
# 860           10          46           56  4ae6ff5cf964a520e5a721e3
# 861           10          46           56  4b994ea1f964a520c57135e3
#
#                     poi_name  poi_distance_from_bike_stn  poi_latitude  \
# 847                  Padella                         143     51.505145
# 848                    fish!                         163     51.505762
# 849  The View From The Shard                         370     51.504267
# 850           The George Inn                         123     51.504003
# 851             Mango Indian                          90     51.504962
# 852           Tapas Brindisa                         100     51.505063
# 853       Oblix At The Shard                         338     51.505253
# 854       The Breakfast Club                          26     51.504555
# 855                     José                         812     51.500500
# 856               Rabot 1745                         150     51.505383
# 857              Boro Bistro                         264     51.506119
# 858   Honest Burgers Borough                          49     51.504574
# 859           Casa do Frango                          79     51.504928
# 860        Kappacasein Dairy                          83     51.505023
# 861          Applebee's Fish                          85     51.505062
#
#      poi_longitude    poi_bsns_category  review_count  rating
# 847      -0.089952  Dining and Drinking         265.0     4.5
# 848      -0.090277  Dining and Drinking         194.0     3.5
# 849      -0.086459  Dining and Drinking         172.0     4.0
# 850      -0.090295  Dining and Drinking         145.0     4.0
# 851      -0.092963  Dining and Drinking         144.0     4.5
# 852      -0.090526  Dining and Drinking         141.0     4.0
# 853      -0.086987  Dining and Drinking         134.0     4.0
# 854      -0.091689  Dining and Drinking         101.0     4.0
# 855      -0.081955  Dining and Drinking          89.0     4.5
# 856      -0.089964  Dining and Drinking          79.0     4.0
# 857      -0.088799  Dining and Drinking          42.0     4.5
# 858      -0.090981  Dining and Drinking           NaN     NaN
# 859      -0.092688  Dining and Drinking           NaN     NaN
# 860      -0.090616  Dining and Drinking           NaN     NaN
# 861      -0.090958  Dining and Drinking           NaN     NaN

# %%
#aggregations of merged data over each bike station to get the average distances of food
#outlets, number of reviews, ratings and number of bikes.

df_agg = df_join.groupby(['bike_station_id']).aggregate(
    {'station_name': 'first',
     'poi_distance_from_bike_stn': 'mean',
     'free_bikes': 'mean',
     'review_count': 'mean',
     'rating': 'mean'})

df_agg = df_agg.round(1)

#validation of sample record to ensure that the aggregated data reflects the transactional merged data.
df_agg[df_agg['station_name'] == '000960 - Hop Exchange, The Borough']
# Out:
#                                                         station_name  \
# bike_station_id
# f8dfc16e9f34e5c21bfc24efe8831549  000960 - Hop Exchange, The Borough
#
#                                   poi_distance_from_bike_stn  free_bikes  \
# bike_station_id
# f8dfc16e9f34e5c21bfc24efe8831549                       191.7        46.0
#
#                                   review_count  rating
# bike_station_id
# f8dfc16e9f34e5c21bfc24efe8831549         136.9     4.1

# %%
review_mean = round(df_agg['review_count'].mean())

rating_mean = round(df_agg['rating'].mean())

df_agg['review_count'].fillna(review_mean, inplace=True)

df_agg['rating'].fillna(rating_mean, inplace=True)

df_agg.to_csv("aggregated_poi_info_for_100_BikeStns.csv", index=False)

df_agg.info()

#total of 100 records created for 100 bike stations with agregations on avergae food outlet distance, number of
#reviews, ratings and number of bikes for each bike station.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0191ad8ece6d587cff8369b58327aacb to f8dfc16e9f34e5c21bfc24efe8831549
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   station_name                100 non-null    object
#  1   poi_distance_from_bike_stn  100 non-null    float64
#  2   free_bikes                  100 non-null    float64
#  3   review_count                100 non-null    float64
#  4   rating                      100 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.7+ KB

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
df_agg.describe()

#the distribution for all variables is spreadout as high standard deviation value shows (except for rating)
# Out:
#        poi_distance_from_bike_stn  free_bikes  review_count      rating
# count                  100.000000  100.000000    100.000000  100.000000
# mean                   254.358000   12.310000    136.887000    4.200000
# std                    104.292619   10.443397     91.843776    0.169967
# min                     75.500000    0.000000     27.000000    3.800000
# 25%                    192.075000    3.000000     79.800000    4.100000
# 50%                    237.150000   11.000000    115.200000    4.200000
# 75%                    298.800000   17.000000    155.325000    4.300000
# max                    773.500000   48.000000    559.900000    4.800000

# %%
# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 14))

# Plot 0
axes[0][0].hist(df_agg['poi_distance_from_bike_stn'],bins=15, color='green')
axes[0][0].set_title('Average food outlet distance a from bike station in london city')
axes[0][0].set_xlabel('Average Distance of food outlets')
axes[0][0].set_ylabel('Count')

# Plot 1
axes[0][1].hist(df_agg['free_bikes'], bins=15, color='blue')
axes[0][1].set_title('Average bike station capacity in london city')
axes[0][1].set_xlabel('Bike capacity')
axes[0][1].set_ylabel('Counts')

# Plot 2
axes[1][0].hist(df_agg['review_count'], bins=15, color='cyan')
axes[1][0].set_title('Average number of reviews for food outlets situated close to bike stations')
axes[1][0].set_xlabel('Average Number of Reviews')
axes[1][0].set_ylabel('Counts')

# Plot 3
axes[1][1].hist(df_agg['rating'], bins=15, color='maroon')
axes[1][1].set_title('Average rating of food outlets situated close to bike stations')
axes[1][1].set_xlabel('Average rating')
axes[1][1].set_ylabel('Counts')

plt.show()

#Average distance of food outlets seems to follow a normal curve sans an outlier.
#Bike capacity is left skewed. So, most bike stations prefer to operate at lower capacity. Only some areas
#operate at high capacity.
#Average number of reviews is also left skewed. 
#Average rating appears close to normal distribution.

# %%
fig, axes = plt.subplots(4, 2, figsize=(14, 18))

axes[0][0].boxplot(df_agg['poi_distance_from_bike_stn'])
axes[0][0].set_title('Average food outlet distance a from bike station (1.5 Quartile)')
axes[0][1].boxplot(df_agg['poi_distance_from_bike_stn'], whis=2.5)
axes[0][1].set_title('Average food outlet distance a from bike station (2.5 Quartile)')

axes[1][0].boxplot(df_agg['free_bikes'])
axes[1][0].set_title('Average bike station capacity in london city (1.5 Quartile)')
axes[1][1].boxplot(df_agg['free_bikes'], whis=2.5)
axes[1][1].set_title('Average bike station capacity in london city (2.5 Quartile)')

axes[2][0].boxplot(df_agg['review_count'])
axes[2][0].set_title('Average number of food outlet reviews (1.5 Quartile)')
axes[2][1].boxplot(df_agg['review_count'], whis=2.5)
axes[2][1].set_title('Average number of food outlet reviews (2.5 Quartile)')

axes[3][0].boxplot(df_agg['rating'])
axes[3][0].set_title('Average food outlet ratings (1.5 Quartile)')
axes[3][1].boxplot(df_agg['rating'], whis=2.5)
axes[3][1].set_title('Average food outlet ratings (2.5 Quartile)')

plt.show()

#The data displays some possible cases of outliers for bike stations where the average distance to food 
#outlet is very high or average number of food outlet reviews is very high which may be on account of 
#promotional campaigns.

# %%
df_agg.corr()

#there is some negative correlation between average distance of bike stations from food outlets and 
#number of food outlets reviews.
# Out:
#                             poi_distance_from_bike_stn  free_bikes  \
# poi_distance_from_bike_stn                    1.000000    0.004724
# free_bikes                                    0.004724    1.000000
# review_count                                 -0.273079    0.198236
# rating                                        0.162732    0.101862
#
#                             review_count    rating
# poi_distance_from_bike_stn     -0.273079  0.162732
# free_bikes                      0.198236  0.101862
# review_count                    1.000000 -0.013453
# rating                         -0.013453  1.000000

# %%
sns.pairplot(df_agg)
plt.show()

#pairplot also shows a negative correlation between distance and number of reviews.

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
import sqlite3 as sqlite

import pandas as pd

from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///bike_stns_poi.db')
sqlite_connection = engine.connect()

# %%
sqlite_table = "london_city_bikes_stns"
df_bike_stns.to_sql(sqlite_table, sqlite_connection, if_exists='replace')

#create a table of bike stations in london city.
# Out:
# 796

# %%
sqlite_table = "bike_stns_poi_details"
df_join.to_sql(sqlite_table, sqlite_connection, if_exists='replace')

#create a table of food outlets close to bike stations along with their reviews, ratings and their average
#distance from the bike stations.
# Out:
# 1072

# %%
sqlite_table = "aggregated_stns_details"
df_agg.to_sql(sqlite_table, sqlite_connection, if_exists='replace')

#create a table with mean aggregations of reviews, ratings and distances for each bike station.
# Out:
# 100

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
sql_query = "select count(*) from bike_stns_poi_details"
engine.execute(sql_query).fetchall()
# Out:
# [(1072,)]

# %%
sql_query = "select count(*) from aggregated_stns_details"
engine.execute(sql_query).fetchall()
# Out:
# [(100,)]
